# %% [markdown]
# <a href="https://colab.research.google.com/github/josmimaria/Machine-Learning/blob/development/Numpy_part_1_Eng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l = [1,2,3,4,5]

# %%
arr = np.array(l)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 = np.array([[1,2,3] , [2,3,4]])

# %%
arr.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
mat = np.matrix(l)

# %%
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.asanyarray(mat)
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = arr

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr[0] = 100

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
a
# Out:
# array([100,   2,   3,   4,   5])

# %%
b = np.copy(arr)

# %%
b
# Out:
# array([100,   2,   3,   4,   5])

# %%
b[0] = 234

# %%
b
# Out:
# array([234,   2,   3,   4,   5])

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
np.fromfunction(lambda i,j : i==j , (3,3))
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
np.fromfunction(lambda i,j : i*j , (3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %%
list(i*i for i in range(5))
# Out:
# [0, 1, 4, 9, 16]

# %%
iterable  = (i*i for i in range(5))

# %%
np.fromiter(iterable,float)
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
np.fromstring('23 45 56',sep  = ' ' )
# Out:
# array([23., 45., 56.])

# %%
np.fromstring('23,45,56',sep  = ',' )
# Out:
# array([23., 45., 56.])

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 5

# %%
arr1.size
# Out:
# 6

# %%
arr.shape
# Out:
# (5,)

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr1.dtype
# Out:
# dtype('int64')
